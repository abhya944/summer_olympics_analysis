# %%
import pandas as pd
import numpy as np
import os
import fileinput
df = pd.read_csv("summer.csv")

# %%
def Display():
    print("==================================================================================")
    print("                               summer olympics ")
    print("==================================================================================")
    
    print("(1) no of unique city  ")
    print("(2) Sport having most Number of Gold Medals So Far")
    print("(3) sport is having most number of medals so far")
    print("(4) player has won most number of medals ")
    print("(5) player has won most number Gold Medals of medals")
    print("(6) Sport having most Number of Gold Medals So Far")
    print("(7) Sport having most Number of Gold Medals So Far")
    print("(8) india won first model...")
    CHOICE = int(input("Enter choice: "))
    menuSelection(CHOICE)

# %%
def menuSelection(CHOICE):
    if CHOICE == 1:
        print("no of unique city")
        print(len(df.City.unique()))  
    elif CHOICE == 2:
        df_gold = df[df['Medal']=='Gold']
        df_gold.groupby('Sport').count()['Medal'].sort_values(ascending=False).head().plot.bar(title ='Sport having most Number of Gold Medals So Far')
    elif CHOICE == 3:
        df.groupby('Sport').count()['Medal'].sort_values(ascending=False).head().plot.bar(title =' sport is having most number of medals so far')
    elif CHOICE == 4:
        df.groupby('Athlete').count()['Medal'].sort_values(ascending=False).head().plot.bar(title =' player has won most number of medals')
    elif CHOICE == 5:
        df_gold = df[df['Medal']=='Gold']
        df_gold.groupby('Athlete').count()['Medal'].sort_values(ascending=False).head().plot.bar(title ='player has won most number Gold Medals of medals')
    elif CHOICE == 6:
        df.groupby('Event').count()['Athlete'].sort_values(ascending=False).head().plot.bar(title ='Sport having most Number of Gold Medals So Far')
    elif CHOICE == 7:
        df_gold = df[df['Medal']=='Gold']
        df_women_gold=df_gold[df_gold['Gender']=='Women']
        df_women_gold.groupby('Sport').count()['Medal'].sort_values(ascending=False).head().plot.bar(title ='Sport having most Number of Gold Medals So Far')
    elif CHOICE == 8:
        for index in range(len(df)):
            if(df.iloc[index]['Medal']=='Gold' and df.iloc[index]['Country']=='IND'):
                print("India won its first gold medal in summer olympics in:")
                print(df.iloc[index]['Year'])
                break

# %%
 Display()
# Out:
# ...
#                                summer olympics
# ...
# (1) no of unique city
# (2) Sport having most Number of Gold Medals So Fa
# (3) sport is having most number of medals so far
# (4) player has won most number of medals
# (5) player has won most number Gold Medals of medals
# (6) Sport having most Number of Gold Medals So Far
# (7) Sport having most Number of Gold Medals So Far
# (8) india won first model...
# (9) exit...
# Enter choice: 1
# no of unique city
# 22

# %%
 Display()
# Out:
# ...
#                                summer olympics
# ...
# (1) no of unique city
# (2) Sport having most Number of Gold Medals So Fa
# (3) sport is having most number of medals so far
# (4) player has won most number of medals
# (5) player has won most number Gold Medals of medals
# (6) Sport having most Number of Gold Medals So Far
# (7) Sport having most Number of Gold Medals So Far
# (8) india won first model...
# (9) exit...
# Enter choice: 2

# %%
 Display()
# Out:
# ...
#                                summer olympics
# ...
# (1) no of unique city
# (2) Sport having most Number of Gold Medals So Fa
# (3) sport is having most number of medals so far
# (4) player has won most number of medals
# (5) player has won most number Gold Medals of medals
# (6) Sport having most Number of Gold Medals So Far
# (7) Sport having most Number of Gold Medals So Far
# (8) india won first model...
# (9) exit...
# Enter choice: 3

# %%
 Display()
# Out:
# ...
#                                summer olympics
# ...
# (1) no of unique city
# (2) Sport having most Number of Gold Medals So Fa
# (3) sport is having most number of medals so far
# (4) player has won most number of medals
# (5) player has won most number Gold Medals of medals
# (6) Sport having most Number of Gold Medals So Far
# (7) Sport having most Number of Gold Medals So Far
# (8) india won first model...
# (9) exit...
# Enter choice: 5

# %%
 Display()
# Out:
# ...
#                                summer olympics
# ...
# (1) no of unique city
# (2) Sport having most Number of Gold Medals So Fa
# (3) sport is having most number of medals so far
# (4) player has won most number of medals
# (5) player has won most number Gold Medals of medals
# (6) Sport having most Number of Gold Medals So Far
# (7) Sport having most Number of Gold Medals So Far
# (8) india won first model...
# (9) exit...
# Enter choice: 6

# %%
 Display()
# Out:
# ...
#                                summer olympics
# ...
# (1) no of unique city
# (2) Sport having most Number of Gold Medals So Far
# (3) sport is having most number of medals so far
# (4) player has won most number of medals
# (5) player has won most number Gold Medals of medals
# (6) Sport having most Number of Gold Medals So Far
# (7) Sport having most Number of Gold Medals So Far
# (8) india won first model...
# Enter choice: 7

# %%
 Display()
# Out:
# ...
#                                summer olympics
# ...
# (1) no of unique city
# (2) Sport having most Number of Gold Medals So Far
# (3) sport is having most number of medals so far
# (4) player has won most number of medals
# (5) player has won most number Gold Medals of medals
# (6) Sport having most Number of Gold Medals So Far
# (7) Sport having most Number of Gold Medals So Far
# (8) india won first model...
# Enter choice: 8
# India won its first gold medal in summer olympics in:
# 1928
